# %%
import requests
import re

# %%
url = "https://www.lyrics.com/artist/Queen/5205"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '\n<!doctype html>\n<!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->\n<!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]--><head>\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<title>Queen Lyrics</title>\n<meta name="description" content="Queen Lyrics - All the great songs and their lyrics from Queen on Lyrics.com">\n<meta name="keywords" content="Queen lyrics, Queen song lyrics, Queen lyric">\n\t<meta name="viewport" content="width=device-width">\n<base href="https://www.lyrics.com/">\n\n<script>s4Prefix=\'https://static.stands4.com\';version=\'1.3.31\';</script>\n\n<!-- Bootstrap compiled and minified CSS -->\n<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.2/css/bootstrap.min.css">\n<!--<link rel="stylesheet" href="--
# ...

# %%
links = '(\/lyric.+?)"'

# %%
urls = re.findall(links, response.text)
urls
# Out:
# ['/lyric/36577956/Queen/Innuendo',
#  '/lyric/36577943/Queen/You+Don%27t+Fool+Me',
#  '/lyric/36577933/Queen/Driven+by+You',
#  '/lyric/35536602/Queen/Somebody+to+Love',
#  '/lyric/35990802/Queen/Doing+All+Right',
#  '/lyric/35536601/Queen/Doing+All+Right...+Revisited',
#  '/lyric/35703948/Queen/Keep+Yourself+Alive',
#  '/lyric/35536599/Queen/Killer+Queen',
#  '/lyric/35703946/Queen/Fat+Bottomed+Girls',
#  '/lyric/35536597/Queen/Bohemian+Rhapsody',
#  '/lyric/35703944/Queen/Now+I%27m+Here',
#  '/lyric/35703942/Queen/Love+of+My+Life',
#  '/lyric/35703941/Queen/We+Will+Rock+You',
#  '/lyric/35536592/Queen/Another+One+Bites+the+Dust',
#  '/lyric/35536591/Queen/I+Want+to+Break+Free',
#  '/lyric/35536590/Queen/Under+Pressure',
#  '/lyric/35536589/Queen/Who+Wants+to+Live+Forever',
#  '/lyric/35703935/Queen/Radio+Ga+Ga',
#  '/lyric/35703933/Queen/Hammer+to+Fall',
#  '/lyric/35703932/Queen/We+Are+the+Champions',
#  '/lyric/35703931/Queen/Don%27t+Stop+Me+Now',
# ...

# %%
import time
"""
for u in urls:
    new_url = 'https://www.lyrics.com' + u
    song = requests.get(new_url)
    filename = u.split("/")[-1]+".txt"
    open(filename, 'w').write(song.text)
    print(new_url, response.status_code)
    time.sleep(3) 
"""
# Out:
# https://www.lyrics.com/lyric/36577956/Queen/Innuendo 200
# https://www.lyrics.com/lyric/36577943/Queen/You+Don%27t+Fool+Me 200
# https://www.lyrics.com/lyric/36577933/Queen/Driven+by+You 200
# https://www.lyrics.com/lyric/35536602/Queen/Somebody+to+Love 200
# https://www.lyrics.com/lyric/35990802/Queen/Doing+All+Right 200
# https://www.lyrics.com/lyric/35536601/Queen/Doing+All+Right...+Revisited 200
# https://www.lyrics.com/lyric/35703948/Queen/Keep+Yourself+Alive 200
# https://www.lyrics.com/lyric/35536599/Queen/Killer+Queen 200
# https://www.lyrics.com/lyric/35703946/Queen/Fat+Bottomed+Girls 200
# https://www.lyrics.com/lyric/35536597/Queen/Bohemian+Rhapsody 200
# https://www.lyrics.com/lyric/35703944/Queen/Now+I%27m+Here 200
# https://www.lyrics.com/lyric/35703942/Queen/Love+of+My+Life 200
# https://www.lyrics.com/lyric/35703941/Queen/We+Will+Rock+You 200
# https://www.lyrics.com/lyric/35536592/Queen/Another+One+Bites+the+Dust 200
# ...

# %%
ConnectionError: HTTPSConnectionPool(host='www.lyrics.com', port=443): Max retries exceeded with url: /lyric/26910240/Queen/Bicycle+Race (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe8693721c0>: Failed to establish a new connection: [Errno 50] Network is down'))
